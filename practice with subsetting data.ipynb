# %%
import numpy as np
import csv
import matplotlib.pyplot as plt
import scipy
import scipy.stats
import math

# %%
data_file = open('/Users/markfang/Dropbox/UCSD Grad work/RNA-Yeo Lab/Data - analyses/SG project/screening/granule area to nuclear area analyses of large screens/150601 cvb smnpc 250 uM tpims/before with controls.csv', 'rU')
data_table = np.genfromtxt(data_file, delimiter=',')

#the actual data is listed in the following rows and columns; the rest are
#data table label strings
FIRSTROW = 4
LASTROW = 100
FIRSTCOLUMN = 1
LASTCOLUMN = 9

SPACING_BTW_CTRLS = 12

data_table = data_table[FIRSTROW:LASTROW, FIRSTCOLUMN:LASTCOLUMN]

original_numrows = data_table.shape[0]
original_numcols = data_table.shape[1]

data_table = data_table.tolist()
#print(data_table)

data_table_withoutctrls = []

for i in range(original_numrows):
    if ((i % SPACING_BTW_CTRLS) != 0) and ((i % SPACING_BTW_CTRLS) != 11):
        data_table_withoutctrls.append(data_table[i])
        
print(data_table_withoutctrls)

#with open ('/Users/markfang/Dropbox/UCSD Grad work/RNA-Yeo Lab/Data - analyses/SG project/screening/granule area to nuclear area analyses of large screens/150601 cvb smnpc 250 uM tpims/before.csv','w') as ctrls_removed_outputfile:
#    writer = csv.writer(ctrls_removed_outputfile, lineterminator = '\n')
#    writer.writerows(data_table_withoutctrls)
# Out:
# [[0.031441685, 0.105491542, 0.092649321, 0.071698666, 0.03066754, 0.065900999, 0.06862701, 0.069507809], [0.036209796, 0.070530611, 0.047241859, 0.082770348, 0.046952159, 0.112549832, 0.077903388, 0.094845359], [0.085354472, 0.068639483, 0.09051427, 0.059099019, 0.093597224, 0.074876241, 0.067900223, 0.049999456], [0.068954285, 0.093321705, 0.115817979, 0.089853556, 0.101355409, 0.110777255, 0.102097967, 0.088636544], [0.054521293, 0.089473269, 0.098807824, 0.081545254, 0.095673161, 0.097708478, 0.088330298, 0.110101187], [0.089130749, 0.116371887, 0.107830852, 0.0980761, 0.09864469, 0.130198702, 0.087120233, 0.101670017], [0.081414192, 0.089293533, 0.101774836, 0.094133194, 0.128464117, 0.115476295, 0.097723288, 0.137870262], [0.068199865, 0.086462667, 0.096314879, 0.134018298, 0.11888839, 0.09776327, 0.115373298, 0.098666383], [0.073212338, 0.122820907, 0.110816077, 0.096157565, 0.095513028, 0.101420991, 0.105455877, 0.096714593], [0.076812132, 0.113505525, 0.071058577, 0.125648379
# ...
